# %% [markdown]
# ### 문제 설명
# # 후보키
# 프렌즈대학교 컴퓨터공학과 조교인 제이지는 네오 학과장님의 지시로, 학생들의 인적사항을 정리하는 업무를 담당하게 되었다.
#
# 그의 학부 시절 프로그래밍 경험을 되살려, 모든 인적사항을 데이터베이스에 넣기로 하였고, 이를 위해 정리를 하던 중에 후보키(Candidate Key)에 대한 고민이 필요하게 되었다.
#
# 후보키에 대한 내용이 잘 기억나지 않던 제이지는, 정확한 내용을 파악하기 위해 데이터베이스 관련 서적을 확인하여 아래와 같은 내용을 확인하였다.
#
# 관계 데이터베이스에서 릴레이션(Relation)의 튜플(Tuple)을 유일하게 식별할 수 있는 속성(Attribute) 또는 속성의 집합 중, 다음 두 성질을 만족하는 것을 후보 키(Candidate Key)라고 한다.
# 유일성(uniqueness) : 릴레이션에 있는 모든 튜플에 대해 유일하게 식별되어야 한다.
# 최소성(minimality) : 유일성을 가진 키를 구성하는 속성(Attribute) 중 하나라도 제외하는 경우 유일성이 깨지는 것을 의미한다. 즉, 릴레이션의 모든 튜플을 유일하게 식별하는 데 꼭 필요한 속성들로만 구성되어야 한다.
# 제이지를 위해, 아래와 같은 학생들의 인적사항이 주어졌을 때, 후보 키의 최대 개수를 구하라.
#
# cand_key1.png
#
# 위의 예를 설명하면, 학생의 인적사항 릴레이션에서 모든 학생은 각자 유일한 "학번"을 가지고 있다. 따라서 "학번"은 릴레이션의 후보 키가 될 수 있다.
# 그다음 "이름"에 대해서는 같은 이름("apeach")을 사용하는 학생이 있기 때문에, "이름"은 후보 키가 될 수 없다. 그러나, 만약 ["이름", "전공"]을 함께 사용한다면 릴레이션의 모든 튜플을 유일하게 식별 가능하므로 후보 키가 될 수 있게 된다.
# 물론 ["이름", "전공", "학년"]을 함께 사용해도 릴레이션의 모든 튜플을 유일하게 식별할 수 있지만, 최소성을 만족하지 못하기 때문에 후보 키가 될 수 없다.
# 따라서, 위의 학생 인적사항의 후보키는 "학번", ["이름", "전공"] 두 개가 된다.
#
# 릴레이션을 나타내는 문자열 배열 relation이 매개변수로 주어질 때, 이 릴레이션에서 후보 키의 개수를 return 하도록 solution 함수를 완성하라.
#
# ### 제한사항
# relation은 2차원 문자열 배열이다.
# relation의 컬럼(column)의 길이는 1 이상 8 이하이며, 각각의 컬럼은 릴레이션의 속성을 나타낸다.
# relation의 로우(row)의 길이는 1 이상 20 이하이며, 각각의 로우는 릴레이션의 튜플을 나타낸다.
# relation의 모든 문자열의 길이는 1 이상 8 이하이며, 알파벳 소문자와 숫자로만 이루어져 있다.
# relation의 모든 튜플은 유일하게 식별 가능하다.(즉, 중복되는 튜플은 없다.)

# %%
# 유일성: 모든 행이 (이름, 전공) 조합에서 중복 없음 → OK
# 최소성: (이름)만 보면 → apeach가 두 번 나옴 → 유일성 깨짐
# (전공)만 보면 → math가 두 번 나옴 → 유일성 깨짐
# → 하나라도 빼면 유일성이 깨지므로 최소성 OK

from collections import deque
def solution(relation):
    answer = 0
    temp = []
    candidate_key = {}

    def dfs(list):
        ## 속성길이 1부터 시작 
        for z in list:
            z = deque(z)
            z.pop()

    # 속성길이 1 컬럼 저장 
    # 딕셔너리로 만들면 어떨지?
    # 속성길이 2, 3 ... 저장 >>
    # 유일성을 제외한 나머지 컬럼에 대해서 
    # 중복이 있으면 유일성 X >
    
    # 속성길이 2 하나라도 다르면 후보키 가능 
    # 속성길이 3 >> 

    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)
    dfs(temp)
        # for j in range(len(relation)):
            # print(j)
    # 속성 길이1 컬럼_1, 2, 3 ...
    # 속성 길이2 컬럼_1, 2, 3 ...
    # 속성 길이3 컬럼_1, 2, 3 ...
    # 속성 길이4 컬럼_1, 2, 3 ...

    return answer

# 각 컬럼 8 이하
# 각 튜플 20 이하
# 문자열 8이하
relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 0

# %%
test = "admin"
row = ["add", "admi", "admn"]
if test in row:
    print("있습니다")

# %%
# 먼저 하나씩 검사 >> 후보키 가능 컬럼 +1 / 제외
from collections import deque
def solution(relation):
    answer = 0
    temp = []
    candidate_key = {}

    def dfs(list):
        ## 속성길이 1부터 시작 
        list = deque(list)
        for z in range(len(list)):
            v = list.popleft()
            for i in list:
                if v in list:
                    print(f"z:{z} 있어요")
                    return 0
        return 1

    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)
    for idx,z in enumerate(temp):
        v = dfs(z) # return 1 or 0
        print(f"v:{v}")
        if v:
            answer += 1
            candidate_key[idx] = z
            temp.pop(idx)
        else:
            continue
    print(f"candidate_key:{candidate_key} temp:{temp}")
    
    return answer

# 제외한 컬럼을 저장하는 변수 vs temp리스트 copy >> copy를 pop 
# temp를 dictionary로 candidate_key를 list로 

# 각 컬럼 8 이하
# 각 튜플 20 이하
# 문자열 8이하
relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# v:1
# z:0 있어요
# v:0
# z:0 있어요
# v:0
# candidate_key:{0: ['100', '200', '300', '400', '500', '600']} temp:[['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 1

# %%
##### 1차 제출
# 제외한 컬럼을 저장하는 변수 vs temp리스트 copy >> copy를 pop 
# temp를 dictionary로 candidate_key를 list로 
# 리스트 / 리스트 카피 
# 리스트 / 세트 키 - 인덱스 번호 밸류 - 컬럼

from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        list = deque(list)
        for z in range(len(list)):
            v = list.popleft()
            for i in list:
                if v in list:
                    print(f"z:{z} 있어요")
                    return 0
        return 1

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        if v:
            answer += 1
            candidate_key[idx] = z
            
        else:
            continue
    print(f"candidate_key:{candidate_key} temp:{temp}")
    # 후보키 pop
    for z in candidate_key:
        temp.pop(z)
        # pop 대신비워버리면?

    # 남은 튜플들 중 여러 컬럼에서 중복은 하나만 가능 

    # dupl에서 바로 return XXXX >> 중복 컬럼의 인덱스 저장 >> 중복컬럼 인덱스 튜플에서 다른 컬럼 확인 
    # >> 중복이 아닌 후보키의 후보를 다음 컬럼에서 확인 할 때 같이 확인 
    # 반복 
    
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# v:1
# z:1 있어요
# v:0
# z:0 있어요
# v:0
# z:0 있어요
# v:0
# candidate_key:{0: ['100', '200', '300', '400', '500', '600']} temp:[['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 1

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            v = list.popleft()
            ## for문 굳이 필요한가? >> 필요함 pop을 해서 뒤에 순서에서는 in으로 확인안됨
            # >> in이 아니라 == 같은지 확인해서 인덱스 알아내야함
            
            for idx,i in enumerate(list):
                if v == i:
                    print(f"z:{z} 있어요 idx:{idx}")
                    dupl_list.append(z)
                    # return 중복 인덱스 리스트
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        
        # 굳이 필요한가 >> 필요하다
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")

    # 후보키 pop >> temp를 계속 돌린다면 candidate에 있는 값 스킵 
    # 또는 temp를 만들 때 같이 리스트를 만들어 관리

    ## dfs? dp? 
    # 중복 튜플 컬럼의 다른 튜플들 같은지 확인 >> 확인 O >> 반대 튜플도 중복컬럼인지 확인 >> 중복이면 검사했던 컬럼에서 중복튜플을 확인 됐던 컬럼과 다시 확인 OO >> 후보키
    # 
    # for z in candidate_key:
    #     temp.pop(z)
    
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3
# v:[1]
# 6
# z:0 있어요 idx:3
# z:0 있어요 idx:4
# z:2 있어요 idx:0
# z:4 있어요 idx:0
# v:[0, 0, 2, 4]
# 6
# z:0 있어요 idx:0
# z:0 있어요 idx:4
# z:1 있어요 idx:3
# z:2 있어요 idx:1
# v:[0, 0, 1, 2]
# ...

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            v = list.popleft()
            ## for문 굳이 필요한가? >> 필요함 pop을 해서 뒤에 순서에서는 in으로 확인안됨
            # >> in이 아니라 == 같은지 확인해서 인덱스 알아내야함
            
            for idx,i in enumerate(list):
                if v == i:
                    print(f"z:{z} 있어요 idx:{idx}")
                    dupl_list.append(z)
                    # return 중복 인덱스 리스트
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        
        # 굳이 필요한가 >> 필요하다
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")

    # 후보키 pop >> temp를 계속 돌린다면 candidate에 있는 값 스킵 
    # 또는 temp를 만들 때 같이 리스트를 만들어 관리

    ## dfs? dp? 
    # 중복 튜플 컬럼의 다른 튜플들 같은지 확인 >> 확인 O >> 반대 튜플도 중복컬럼인지 확인 >> 중복이면 검사했던 컬럼에서 중복튜플을 확인 됐던 컬럼과 다시 확인 OO >> 후보키
    # 
    # for z in candidate_key:
    #     temp.pop(z)
    
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            v = list.popleft()
            ## for문 굳이 필요한가? >> 필요함 pop을 해서 뒤에 순서에서는 in으로 확인안됨
            # >> in이 아니라 == 같은지 확인해서 인덱스 알아내야함
            
            for idx,i in enumerate(list):
                if v == i:
                    print(f"z:{z} 있어요 idx:{idx}")
                    dupl_list.append([z,idx+1+z])
                    # return 중복 인덱스 
                    print(f"dupl_list:{dupl_list}")
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        
        # 굳이 필요한가 >> 필요하다
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")

    # 후보키 pop >> temp를 계속 돌린다면 candidate에 있는 값 스킵 
    # 또는 temp를 만들 때 같이 리스트를 만들어 관리

    ## dfs? dp? 
    # 중복 튜플 컬럼의 다른 튜플들 같은지 확인 >> 확인 O >> 반대 튜플도 중복컬럼인지 확인 >> 중복이면 검사했던 컬럼에서 중복튜플을 확인 됐던 컬럼과 다시 확인 OO >> 후보키
    # 
    # for z in candidate_key:
    #     temp.pop(z)
    
    # 같은 인덱스 묶어야됨
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3
# dupl_list:[[1, 5]]
# v:[[1, 5]]
# 6
# z:0 있어요 idx:3
# dupl_list:[[0, 4]]
# z:0 있어요 idx:4
# dupl_list:[[0, 4], [0, 5]]
# z:2 있어요 idx:0
# dupl_list:[[0, 4], [0, 5], [2, 3]]
# z:4 있어요 idx:0
# dupl_list:[[0, 4], [0, 5], [2, 3], [4, 5]]
# v:[[0, 4], [0, 5], [2, 3], [4, 5]]
# 6
# z:0 있어요 idx:0
# ...

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            same_vals = []

            v = list.popleft()
            ## for문 굳이 필요한가? >> 필요함 pop을 해서 뒤에 순서에서는 in으로 확인안됨
            # >> in이 아니라 == 같은지 확인해서 인덱스 알아내야함
            # 사용했던 elmts 빈리스트로?
            
            for idx,i in enumerate(list):
                if v == i:
                    
                    # dupl_list에 들어있는지 확인
                    
                    if idx+1+z in same_vals:
                        continue

                    if z in same_vals:
                        same_vals.append(idx+1+z)
                    else:
                        same_vals = [z]
                        same_vals.append(idx+1+z)

                    print(f"z:{z} 있어요 idx:{idx} sanme_vals:{same_vals}")
            # 빈리스트 저장 방지
            if not same_vals:
                continue

            dupl_list.append(same_vals)
                    # return 중복 인덱스 
            print(f"dupl_list:{dupl_list}")
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        
        # 굳이 필요한가 >> 필요하다
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")

    # 후보키 pop >> temp를 계속 돌린다면 candidate에 있는 값 스킵 
    # 또는 temp를 만들 때 같이 리스트를 만들어 관리

    ## dfs? dp? 
    # 중복 튜플 컬럼의 다른 튜플들 같은지 확인 >> 확인 O >> 반대 튜플도 중복컬럼인지 확인 >> 중복이면 검사했던 컬럼에서 중복튜플을 확인 됐던 컬럼과 다시 확인 OO >> 후보키
    # 
    # for z in candidate_key:
    #     temp.pop(z)
    
    # 같은 인덱스 묶어야됨
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
### 이미 dupl_list에 있다면 제외 해야됨
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3 sanme_vals:[1, 5]
# dupl_list:[[1, 5]]
# v:[[1, 5]]
# 6
# z:0 있어요 idx:3 sanme_vals:[0, 4]
# z:0 있어요 idx:4 sanme_vals:[0, 4, 5]
# dupl_list:[[0, 4, 5]]
# z:2 있어요 idx:0 sanme_vals:[2, 3]
# dupl_list:[[0, 4, 5], [2, 3]]
# z:4 있어요 idx:0 sanme_vals:[4, 5]
# dupl_list:[[0, 4, 5], [2, 3], [4, 5]]
# ...

# %%
d = [[0, 4, 5], [2, 3]]

for i in d:
    if [4,5] in d:
        print(f"i:{i} 있어요")
    print(i)
# Out:
# [0, 4, 5]
# [2, 3]

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            same_vals = []

            v = list.popleft()
            ## for문 굳이 필요한가? >> 필요함 pop을 해서 뒤에 순서에서는 in으로 확인안됨
            # >> in이 아니라 == 같은지 확인해서 인덱스 알아내야함
            # 사용했던 elmts 빈리스트로?
            
            for idx,i in enumerate(list):
                break_b = False
                if v == i:
                    
                    # dupl_list에 들어있는지 
                    # continue는 밑에 for문에서만 continue
                    for j in dupl_list:
                        if z in j:
                            print(f"z:{z} j:{j} 들어있는지")
                            break_b = True
                    if break_b:
                        continue        

                    if z in same_vals:
                        same_vals.append(idx+1+z)
                    else:
                        same_vals = [z]
                        same_vals.append(idx+1+z)

                    print(f"z:{z} 있어요 idx:{idx} sanme_vals:{same_vals}")
            # 빈리스트 저장 방지
            if not same_vals:
                continue

            dupl_list.append(same_vals)
                    # return 중복 인덱스 
            print(f"dupl_list:{dupl_list}")
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        
        # 굳이 필요한가 >> 필요하다
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")

    # 후보키 pop >> temp를 계속 돌린다면 candidate에 있는 값 스킵 
    # 또는 temp를 만들 때 같이 리스트를 만들어 관리

    ## dfs? dp? 
    # 중복 튜플 컬럼의 다른 튜플들 같은지 확인 >> 확인 O >> 반대 튜플도 중복컬럼인지 확인 >> 중복이면 검사했던 컬럼에서 중복튜플을 확인 됐던 컬럼과 다시 확인 OO >> 후보키
    # 
    # for z in candidate_key:
    #     temp.pop(z)
    
    # 같은 인덱스 묶어야됨
    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
### 이미 dupl_list에 있다면 제외 해야됨
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3 sanme_vals:[1, 5]
# dupl_list:[[1, 5]]
# v:[[1, 5]]
# 6
# z:0 있어요 idx:3 sanme_vals:[0, 4]
# z:0 있어요 idx:4 sanme_vals:[0, 4, 5]
# dupl_list:[[0, 4, 5]]
# z:2 있어요 idx:0 sanme_vals:[2, 3]
# dupl_list:[[0, 4, 5], [2, 3]]
# z:4 j:[0, 4, 5] 들어있는지
# v:[[0, 4, 5], [2, 3]]
# 6
# z:0 있어요 idx:0 sanme_vals:[0, 1]
# ...

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list = deque(list)
        len_l = len(list)
        print(len(list))
        
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            same_vals = []

            v = list.popleft()
            
            for idx,i in enumerate(list):
                break_b = False
                if v == i:
                    
                    # dupl_list에 들어있는지 
                    # continue는 밑에 for문에서만 continue
                    for j in dupl_list:
                        if z in j:
                            print(f"z:{z} j:{j} 들어있는지")
                            break_b = True
                    if break_b:
                        continue        

                    if z in same_vals:
                        same_vals.append(idx+1+z)
                    else:
                        same_vals = [z]
                        same_vals.append(idx+1+z)

                    print(f"z:{z} 있어요 idx:{idx} sanme_vals:{same_vals}")
            # 빈리스트 저장 방지
            if not same_vals:
                continue

            dupl_list.append(same_vals)
                    # return 중복 인덱스 
            print(f"dupl_list:{dupl_list}")
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        if not v:
            answer += 1
            candidate_key.append(idx)
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")
    
    # dupl_idx_dict 돌면서 검사 >> 검사할 때 반대쪽 컬럼에서도 검사
    for d_one in dupl_idx_dict:
        print(dupl_idx_dict[d_one])


    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3 sanme_vals:[1, 5]
# dupl_list:[[1, 5]]
# v:[[1, 5]]
# 6
# z:0 있어요 idx:3 sanme_vals:[0, 4]
# z:0 있어요 idx:4 sanme_vals:[0, 4, 5]
# dupl_list:[[0, 4, 5]]
# z:2 있어요 idx:0 sanme_vals:[2, 3]
# dupl_list:[[0, 4, 5], [2, 3]]
# z:4 j:[0, 4, 5] 들어있는지
# v:[[0, 4, 5], [2, 3]]
# 6
# z:0 있어요 idx:0 sanme_vals:[0, 1]
# ...

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []
    # 튜플의 중복인덱스 짝 리스트 필요 
    dupl_idx_dict = {}

    def dupl(list_):
        ## 속성길이 1부터 시작 
        dupl_list = []
        list_ = deque(list_)
        len_l = len(list_)
        print(len(list_))
        
        # pop하면서 range범위때메 잘림
        for z in range(len_l):
            same_vals = []

            v = list_.popleft()
            
            for idx,i in enumerate(list_):
                break_b = False
                if v == i:
                    
                    # dupl_list에 들어있는지 
                    # continue는 밑에 for문에서만 continue
                    for j in dupl_list:
                        if z in j:
                            print(f"z:{z} j:{j} 들어있는지")
                            break_b = True
                    if break_b:
                        continue        

                    if z in same_vals:
                        same_vals.append(idx+1+z)
                    else:
                        same_vals = [z]
                        same_vals.append(idx+1+z)

                    print(f"z:{z} 있어요 idx:{idx} sanme_vals:{same_vals}")
            # 빈리스트 저장 방지
            if not same_vals:
                continue

            dupl_list.append(same_vals)
                    # return 중복 인덱스 
            print(f"dupl_list:{dupl_list}")
        return dupl_list
        # 빈 리스트

    # 컬럼별로 분류
    for i in range(len(relation[0])):
        column = []
        # +1 +2 
        for j in relation:
            print(j[i])
            column.append(j[i])

        temp.append(column)
        print(temp)

    # 후보키만 candi dict에 추가 
    for idx,z in enumerate(temp):
        v = dupl(z) # return 1 or 0
        print(f"v:{v}")
        
        if not v:
            answer += 1
            candidate_key.append((idx,))
            
        else:
            dupl_idx_dict[idx] = v
    print(f"candidate_key:{candidate_key} temp:{temp}")
    print(f"dupl_idx_dict: {dupl_idx_dict}")
    
    # dupl_idx_dict 돌면서 검사 >> 검사할 때 반대쪽 컬럼에서도 검사
    for key1 in dupl_idx_dict:
        if any(set(ck).issubset({key1}) for ck in candidate_key):
            continue

        groups = dupl_idx_dict[key1]
        print(f"groups: {groups}")
        is_candidate = True
        for group in groups:
            check = []
            for key2 in dupl_idx_dict:
                if key2 == key1:
                    continue

                # key2 컬럼에서 group에 있는 인덱스들 값 
                vals = [temp[key2][i] for i in group]
                # 값 같은지 확인
                if len(set(vals)) == 1: # 모두 같으면 후보키 아님 
                    check.append(True)
            if len(check) == len(groups):
                is_candidate = False
                break
        if is_candidate:
            candidate_key.append((key1,))
            answer +=1

    return answer

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

# result 2
solution(relation)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# [['100', '200', '300', '400', '500', '600']]
# ryan
# apeach
# tube
# con
# muzi
# apeach
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach']]
# music
# math
# computer
# computer
# music
# music
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music']]
# 2
# 2
# 3
# 4
# 3
# 2
# [['100', '200', '300', '400', '500', '600'], ['ryan', 'apeach', 'tube', 'con', 'muzi', 'apeach'], ['music', 'math', 'computer', 'computer', 'music', 'music'], ['2', '2', '3', '4', '3', '2']]
# 6
# v:[]
# 6
# z:1 있어요 idx:3 sanme_vals:[1, 5]
# dupl_list:[[1, 5]]
# v:[[1, 5]]
# 6
# z:0 있어요 idx:3 sanme_vals:[0, 4]
# z:0 있어요 idx:4 sanme_vals:[0, 4, 5]
# dupl_list:[[0, 4, 5]]
# z:2 있어요 idx:0 sanme_vals:[2, 3]
# dupl_list:[[0, 4, 5], [2, 3]]
# z:4 j:[0, 4, 5] 들어있는지
# v:[[0, 4, 5], [2, 3]]
# 6
# z:0 있어요 idx:0 sanme_vals:[0, 1]
# ...

# %%
# 1>>2 / 1>>3 / 1>>2,3
# 2>>3

check = []
test = [1,2,3]
test_1 = ["일","이","삼"]
len_test = len(test) - 1
print(len_test)
temp = []
for idx,i in enumerate(test):
    print(f"len_test-i:{len_test-idx} i : {i}")

    for j in range(len_test-idx):
        print(f"i:{i} j: {j}")
# Out:
# 2
# len_test-i:2 i : 1
# i:1 j: 0
# i:1 j: 1
# len_test-i:1 i : 2
# i:2 j: 0
# len_test-i:0 i : 3

# %%
# gpt답
from itertools import combinations

def solution(relation):
    n_row = len(relation)
    n_col = len(relation[0])
    candidates = []

    for r in range(1, n_col+1):
        for comb in combinations(range(n_col), r):
            # 최소성 체크
            if any(set(ck).issubset(set(comb)) for ck in candidates):
                print("최소성검사")
                continue
            # 유일성 체크
            if len({tuple(row[c] for c in comb) for row in relation}) == n_row:
                candidates.append(comb)
                print(candidates)
    return len(candidates)

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]

solution(relation)
# Out:
# [(0,)]
# 최소성검사
# 최소성검사
# 최소성검사
# [(0,), (1, 2)]
# 최소성검사
# 최소성검사
# 최소성검사
# 최소성검사
# 최소성검사
# 2

# %%
from itertools import combinations

relation = [["100","ryan","music","2"],["200","apeach","math","2"],["300","tube","computer","3"],["400","con","computer","4"],["500","muzi","music","3"],["600","apeach","music","2"]]
n_row = len(relation)
n_col = len(relation[0])
candidates = []

for r in range(1, n_col+1):
    for comb in combinations(range(n_col), r):
        print(comb)
# Out:
# (0,)
# (1,)
# (2,)
# (3,)
# (0, 1)
# (0, 2)
# (0, 3)
# (1, 2)
# (1, 3)
# (2, 3)
# (0, 1, 2)
# (0, 1, 3)
# (0, 2, 3)
# (1, 2, 3)
# (0, 1, 2, 3)

# %%
from collections import deque

def solution(relation):
    answer = 0
    temp = []
    candidate_key = []  # 후보키를 튜플로 저장
    dupl_idx_dict = {}

    # 단일 컬럼 중복 인덱스 확인
    def dupl(list_):
        dupl_list = []
        list_ = deque(list_)
        len_l = len(list_)
        
        for z in range(len_l):
            same_vals = []
            v = list_.popleft()
            
            for idx, i in enumerate(list_):
                break_b = False
                if v == i:
                    for j in dupl_list:
                        if z in j:
                            break_b = True
                    if break_b:
                        continue

                    if z in same_vals:
                        same_vals.append(idx+1+z)
                    else:
                        same_vals = [z]
                        same_vals.append(idx+1+z)

            if same_vals:
                dupl_list.append(same_vals)
        return dupl_list

    # 컬럼별 값 분리
    for i in range(len(relation[0])):
        column = [row[i] for row in relation]
        temp.append(column)

    # 단일 컬럼 후보키 확인
    for idx, col in enumerate(temp):
        v = dupl(col)
        if not v:  # 중복 없음 → 후보키
            candidate_key.append((idx,))
            answer += 1
        else:
            dupl_idx_dict[idx] = v

    # 단일 컬럼 후보키를 제외한 후보키 조합 탐색
    from itertools import combinations

    all_cols = list(range(len(temp)))
    for r in range(2, len(temp)+1):
        for comb in combinations(all_cols, r):
            # 최소성 체크: 이미 후보키에 포함된 컬럼 조합이면 건너뛰기
            if any(set(ck).issubset(set(comb)) for ck in candidate_key):
                continue

            # 유일성 체크
            tuples = [tuple(row[c] for c in comb) for row in relation]
            if len(set(tuples)) == len(relation):
                candidate_key.append(comb)
                answer += 1

    return answer


# 테스트
relation = [
    ["100","ryan","music","2"],
    ["200","apeach","math","2"],
    ["300","tube","computer","3"],
    ["400","con","computer","4"],
    ["500","muzi","music","3"],
    ["600","apeach","music","2"]
]
# answer 2

print(solution(relation))
# Out:
# 2
