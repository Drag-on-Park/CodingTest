# %% [markdown]
# ### 문제 설명
# 0 또는 양의 정수가 주어졌을 때, 정수를 이어 붙여 만들 수 있는 가장 큰 수를 알아내 주세요.
#
# 예를 들어, 주어진 정수가 [6, 10, 2]라면 [6102, 6210, 1062, 1026, 2610, 2106]를 만들 수 있고, 이중 가장 큰 수는 6210입니다.
#
# 0 또는 양의 정수가 담긴 배열 numbers가 매개변수로 주어질 때, 순서를 재배치하여 만들 수 있는 가장 큰 수를 문자열로 바꾸어 return 하도록 solution 함수를 작성해주세요.
#
# ### 제한 사항
# numbers의 길이는 1 이상 100,000 이하입니다.
# numbers의 원소는 0 이상 1,000 이하입니다.
# 정답이 너무 클 수 있으니 문자열로 바꾸어 return 합니다.

# %%
def solution(numbers):
    answer = ''
    str_list = []
    len_num = len(numbers)

    def rec_num(idx,nums,start,created_l):
        pass
        
        for i in range(start,len(nums)):
            e_list = rec_num(i+1,nums,)
        # str_list.append(e_list)
    str_list = rec_num(0,numbers,0,[])
    
    # # str_list.sort()
    # answer = str_list[0]
    return answer

numbers = [6, 10, 2]
# return	"6210"
numbers = [3, 30, 34, 5, 9]
# return "9534330"
solution(numbers)

# %%
def solution(numbers):
    answer = ''
    str_list = []
    len_num = len(numbers)
    int_e_list = []

    def rec_num(idx,nums,created_l):
        pass

        str_num = ''
        str_num += nums[idx]

        for i in range(len(nums)):
            if idx == i:
                continue
            str_num += str(nums[i])
        created_l.append(str(nums[i]))


    for idx in range(len_num):
        e_list = rec_num(idx,numbers,[])
        # for i in e_list:
        #     int_e_list.append(int(i))
        # max_e_list = max(int_e_list)
        # str_list.append(max_e_list)

    
    # str_list = max(str_list)
    
    # answer = str_list
    return answer

numbers = [6, 10, 2]
# return	"6210"
numbers = [3, 30, 34, 5, 9]
# return "9534330"
solution(numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 37
#      35 numbers = [3, 30, 34, 5, 9]
#      36 # return "9534330"
# ---> 37 solution(numbers)
#
# Cell In[2], line 21, in solution(numbers)
#      17     created_l.append(str(nums[i]))
#      20 for idx in range(len_num):
# ---> 21     e_list = rec_num(idx,numbers,[])
#      22     # for i in e_list:
#      23     #     int_e_list.append(int(i))
#      24     # max_e_list = max(int_e_list)
#    (...)
#      29
#      30 # answer = str_list
#      31 return answer
#
# Cell In[2], line 11, in solution.<locals>.rec_num(idx, nums, created_l)
#       8 pass
#      10 str_num = ''
# ---> 11 str_num += nums[idx]
#      13 for i in range(len(nums)):
#      14     if idx == i:
#
# TypeError: can only concatenate str (not "int") to str

# %%
import functools

# sort()
# 큰숫자를 만드는 방법
def solution(numbers):
    answer = ''
    for idx,i in enumerate(numbers):
        numbers[idx] = str(i)
    def comparator(a, b):
        if a+b > b+a:
            return -1
        elif a+b < b+a:
            return 1
        else:
            return 0
        
    numbers.sort(key=functools.cmp_to_key(comparator))
    answer = answer.join(numbers)

    if answer[0] == '0':
        return '0'

    print(numbers)

    # str_list = []
    # len_num = len(numbers)
    # int_e_list = []

    # def rec_num(idx,nums,created_l):
    #     pass

    #     str_num = ''
    #     str_num += nums[idx]

    #     for i in range(len(nums)):
    #         if idx == i:
    #             continue
    #         str_num += str(nums[i])
    #     created_l.append(str(nums[i]))


    # for idx in range(len_num):
    #     e_list = rec_num(idx,numbers,[])
    #     # for i in e_list:
    #     #     int_e_list.append(int(i))
    #     # max_e_list = max(int_e_list)
    #     # str_list.append(max_e_list)

    
    # # str_list = max(str_list)
    
    # # answer = str_list
    return answer

numbers = [6, 10, 2]
# return	"6210"
numbers = [3, 30, 34, 5, 9]
# return "9534330"
solution(numbers)
# Out:
# ['9', '5', '34', '3', '30']
# '9534330'

# %%
import functools

# sort()
# 큰숫자를 만드는 방법
def solution(numbers):
    answer = ''
    for idx,i in enumerate(numbers):
        numbers[idx] = str(i)
    def comparator(a, b):
        if a+b > b+a:
            return -1
        elif a+b < b+a:
            return 1
        else:
            return 0
        
    numbers.sort(key=functools.cmp_to_key(comparator))
    answer = answer.join(numbers)

    if answer[0] == '0':
        return '0'

    print(numbers)
    return answer

numbers = [6, 10, 2]
# return	"6210"
numbers = [3, 30, 34, 5, 9]
# return "9534330"
solution(numbers)
