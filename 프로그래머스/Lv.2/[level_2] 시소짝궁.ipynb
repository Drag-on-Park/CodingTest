# %% [markdown]
# ### 문제 설명
# 어느 공원 놀이터에는 시소가 하나 설치되어 있습니다. 이 시소는 중심으로부터 2(m), 3(m), 4(m) 거리의 지점에 좌석이 하나씩 있습니다.
# 이 시소를 두 명이 마주 보고 탄다고 할 때, 시소가 평형인 상태에서 각각에 의해 시소에 걸리는 토크의 크기가 서로 상쇄되어 완전한 균형을 이룰 수 있다면 그 두 사람을 시소 짝꿍이라고 합니다. 즉, 탑승한 사람의 무게와 시소 축과 좌석 간의 거리의 곱이 양쪽 다 같다면 시소 짝꿍이라고 할 수 있습니다.
# 사람들의 몸무게 목록 weights이 주어질 때, 시소 짝꿍이 몇 쌍 존재하는지 구하여 return 하도록 solution 함수를 완성해주세요.
#
# ### 제한 사항
# 2 ≤ weights의 길이 ≤ 100,000
# 100 ≤ weights[i] ≤ 1,000
# 몸무게 단위는 N(뉴턴)으로 주어집니다.
# 몸무게는 모두 정수입니다.

# %%
## 시간초과
def solution(weights):
    answer = 0
    # 234
    l_list = []
    
    len_w = len(weights)
    for i in range(len_w):
        weights_c = weights.copy()
        x = weights_c.pop(i)
        print(x)
        l_list = [x*2,x*3,x*4]
        print(l_list)
        for j in range(i+1,len_w):
            if weights[j] == x:
                answer += 1
                continue
            for k in range(2,5):
                
                if weights[j] * k in l_list:
                    print(f"weights[j]: {weights[j]} k: {k}")
                    print(f"l_list:{l_list} weights[j]: {weights[j]} ")
                    answer += 1
        
    return answer

weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# 100
# [200, 300, 400]
# 180
# [360, 540, 720]
# weights[j]: 360 k: 2
# l_list:[360, 540, 720] weights[j]: 360
# weights[j]: 270 k: 2
# l_list:[360, 540, 720] weights[j]: 270
# 360
# [720, 1080, 1440]
# weights[j]: 270 k: 4
# l_list:[720, 1080, 1440] weights[j]: 270
# 100
# [200, 300, 400]
# 270
# [540, 810, 1080]
# 4

# %%
# set?
## 시간초과
# weights 3개 최대값은 250 (x4
# 2개 최댓값 333 (x3
# 1개 최댓값 1000 (x2

def solution(weights):
    answer = 0
    # 234
    l_list = []
    dict_w = {}

    for i in weights:
        if i not in dict_w:
            if i <= 250:
                dict_w[i] = [i*2,i*3,i*4]
            elif i < 334:
                dict_w[i] = [i*2,i*3]
            elif i <= 500:
                dict_w[i] = [i*2]

        else:
            # 있으니까 확인 후 +1 
            
            
    
    len_w = len(weights)
    for i in range(len_w):
        weights_c = weights.copy()
        x = weights_c.pop(i)
        print(x)
        l_list = [x*2,x*3,x*4]
        print(l_list)
        for j in range(i+1,len_w):
            if weights[j] == x:
                answer += 1
                continue
            for k in range(2,5):
                
                if weights[j] * k in l_list:
                    print(f"weights[j]: {weights[j]} k: {k}")
                    print(f"l_list:{l_list} weights[j]: {weights[j]} ")
                    answer += 1
        
    return answer

weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# 100
# [200, 300, 400]
# 180
# [360, 540, 720]
# weights[j]: 360 k: 2
# l_list:[360, 540, 720] weights[j]: 360
# weights[j]: 270 k: 2
# l_list:[360, 540, 720] weights[j]: 270
# 360
# [720, 1080, 1440]
# weights[j]: 270 k: 4
# l_list:[720, 1080, 1440] weights[j]: 270
# 100
# [200, 300, 400]
# 270
# [540, 810, 1080]
# 4

# %%
# 1. weights의 길이는 최대 99,999개이지만 그 범주는 901개밖에 되지 않으며, 이를 고려해서 각 범주별 개수를 구한뒤 풀면 속도제한에 걸리지 않는다.
# (from collections import Counter)

# 2. 범주별로 개수를 구했다면, 페어가 되는 경우의 수를 구현해야 한다. 경우의 수는 다음과 같다.

# 3. 동일한 무게 : 동일한 거리에 앉으면 됨

# 4. 다른 무게 : 다른 거리에 앉아야 하며, 이때 2m&4m, 2m&3m, 3m&4m에 앉는 경우가 


# 100 > 200 300 400
# 1000> 2000 3000 4000

900 1800 2700 3600
950 1900 2850 3800

901
# list > leftpop 

def solution(weights):
    answer = 0
    # 234
    l_list = []
    dict_w = {}

    for i in weights:
        if i not in dict_w:
            if i <= 250:
                dict_w[i] = [i*2,i*3,i*4]
            elif i < 334:
                dict_w[i] = [i*2,i*3]
            elif i <= 500:
                dict_w[i] = [i*2]

        else:
            # 있으니까 확인 후 +1 
            
            
    
    len_w = len(weights)
    for i in range(len_w):
        weights_c = weights.copy()
        x = weights_c.pop(i)
        print(x)
        l_list = [x*2,x*3,x*4]
        print(l_list)
        for j in range(i+1,len_w):
            if weights[j] == x:
                answer += 1
                continue
            for k in range(2,5):
                
                if weights[j] * k in l_list:
                    print(f"weights[j]: {weights[j]} k: {k}")
                    print(f"l_list:{l_list} weights[j]: {weights[j]} ")
                    answer += 1
        
    return answer

weights = [100,180,360,100,270]
# result 4
solution(weights)

# %%
# 1. weights의 길이는 최대 99,999개이지만 그 범주는 901개밖에 되지 않으며, 이를 고려해서 각 범주별 개수를 구한뒤 풀면 속도제한에 걸리지 않는다.
# (from collections import Counter)

# 2. 범주별로 개수를 구했다면, 페어가 되는 경우의 수를 구현해야 한다. 경우의 수는 다음과 같다.

# 3. 동일한 무게 : 동일한 거리에 앉으면 됨

# 4. 다른 무게 : 다른 거리에 앉아야 하며, 이때 2m&4m, 2m&3m, 3m&4m에 앉는 경우가 

# set() 중복X
# 중복된 수를 구할 때는??

# list > leftpop 
from collections import deque
def solution(weights):
    answer = 0
    check_list = []
    dict_w = {}
    target = deque(weights)

    for z in weights:
        if z not in dict_w:
            dict_w[z] = 1
        else: 
            dict_w[z] += 1
    print(dict_w)
    dict_l = list(dict_w)
    dict_l.sort()
    target = deque(dict_l)
    
    # 100 2개 200 1개 >> ??
    for i in dict_l:
        if dict_w[i] != 1:
            # 2이상 일 때 
            answer += dict_w[i] - 1
        print(f"answer: {answer}")
        v = target.popleft()
        
        for j in target:
            print(f"v:{v} j:{j}")
            # if v*4 < j*2:
            #     break
            if v*2 == j*3 or v*2 == j*4:
                print("2")
                answer += 1
                continue
            elif v*3 == j*2 or v*3 == j*4:
                print("3")
                answer += 1
                continue
            elif v*4 == j*2 or v*4 == j*3:
                print("4")
                answer += 1
                continue

        # check_list = [v*2,v*3,v*4]
        # 2&3 2&4 / 3&2 3&4 / 4&2 4&3
        # for j in target:
    #         if i == j:
    #             answer += 1
    #             continue
            
        
    return answer

weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# {100: 2, 180: 1, 360: 1, 270: 1}
# answer: 1
# v:100 j:180
# v:100 j:270
# v:100 j:360
# answer: 1
# v:180 j:270
# 3
# v:180 j:360
# 4
# answer: 3
# v:270 j:360
# 4
# answer: 4
# 4

# %%
from collections import deque
def solution(weights):
    answer = 0
    check_list = []
    dict_w = {}
    target = deque(weights)

    for z in weights:
        if z not in dict_w:
            dict_w[z] = 1
        else: 
            dict_w[z] += 1
    dict_l = list(dict_w)
    dict_l.sort()
    target = deque(dict_l)
    
    # 100 2개 200 1개 >> ??
    for i in dict_l:
        # 조합으로 경우의수
        if dict_w[i] != 1:
            # 2이상 일 때 
            answer += int(dict_w[i]*(dict_w[i]-1)/2)
        v = target.popleft()
        
        for j in target:
            # if v*4 < j*3:
            #     break
            temp = [int(ratio * v) for ratio in [2/3, 2/4, 3/2, 3/4, 4/2, 4/3]]
            # temp = [ratio * v for ratio in [2/3, 2/4, 3/2, 3/4, 4/2, 4/3]]
            print(f"temp:{temp} i:{i} j:{j}")
            if j in temp:
                answer += 1
                continue

            # if v*2/3 == j or v*2/4 == j:
            #     answer += 1
            #     continue
            # elif v*3 == j*2 or v*3 == j*4:
            #     answer += 1
            #     continue
            # elif v*4 == j*2 or v*4 == j*3:
            #     answer += 1
            #     continue
    return answer
weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# temp:[66, 50, 150, 75, 200, 133] i:100 j:180
# temp:[66, 50, 150, 75, 200, 133] i:100 j:270
# temp:[66, 50, 150, 75, 200, 133] i:100 j:360
# temp:[120, 90, 270, 135, 360, 240] i:180 j:270
# temp:[120, 90, 270, 135, 360, 240] i:180 j:360
# temp:[180, 135, 405, 202, 540, 360] i:270 j:360
# 4

# %%
from collections import deque
def solution(weights):
    answer = 0
    check_list = []
    dict_w = {}
    target = deque(weights)

    for z in weights:
        if z not in dict_w:
            dict_w[z] = 1
        else: 
            dict_w[z] += 1
    dict_l = list(dict_w)
    dict_l.sort()
    target = deque(dict_l)
    
    # 100 2개 200 1개 >> ??
    for i in dict_l:
        # 조합으로 경우의수
        if dict_w[i] != 1:
            # 2이상 일 때 
            answer += int(dict_w[i]*(dict_w[i]-1)/2)
        v = target.popleft()
        
        for j in target:
            # if v*4 < j*3:
            #     break
            temp = [int(ratio * v) for ratio in [2/3, 2/4, 3/2, 3/4, 4/2, 4/3]]
            # temp = [ratio * v for ratio in [2/3, 2/4, 3/2, 3/4, 4/2, 4/3]]
            print(f"temp:{temp} i:{i} j:{j}")
            if j in temp:
                answer += dict_w[v] * dict_w[j]
                continue

            # if v*2/3 == j or v*2/4 == j:
            #     answer += 1
            #     continue
            # elif v*3 == j*2 or v*3 == j*4:
            #     answer += 1
            #     continue
            # elif v*4 == j*2 or v*4 == j*3:
            #     answer += 1
            #     continue
    return answer
weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# temp:[66, 50, 150, 75, 200, 133] i:100 j:180
# temp:[66, 50, 150, 75, 200, 133] i:100 j:270
# temp:[66, 50, 150, 75, 200, 133] i:100 j:360
# temp:[120, 90, 270, 135, 360, 240] i:180 j:270
# temp:[120, 90, 270, 135, 360, 240] i:180 j:360
# temp:[180, 135, 405, 202, 540, 360] i:270 j:360
# 4

# %%
from collections import deque
def solution(weights):
    answer = 0
    check_list = []
    dict_w = {}
    target = deque(weights)

    for z in weights:
        if z not in dict_w:
            dict_w[z] = 1
        else: 
            dict_w[z] += 1
    dict_l = list(dict_w)
    dict_l.sort()
    target = deque(dict_l)
    
    # 100 2개 200 1개 >> ??
    for idx,i in enumerate(dict_l):
        # 조합으로 경우의수
        if dict_w[i] != 1:
            # 2이상 일 때 
            answer += int(dict_w[i]*(dict_w[i]-1)/2)
        v = i
        
        for j in dict_l[idx+1:]:
            if v*2 % 3 == 0:
                candidate = v*2//3 
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]
            if v*2 % 4 == 0:
                candidate = v*2//4 
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]
            if v*3 % 2 == 0:
                candidate = v*3//2
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]
            if v*3 % 4 == 0:
                candidate = v*3//4 
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]
            if v*4 % 2 == 0:
                candidate = v*4//2 
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]
            if v*4 % 3 == 0:
                candidate = v*4//3 
                if candidate == j:
                    answer += dict_w[v] * dict_w[candidate]

    return answer
weights = [100,180,360,100,270]
# result 4
solution(weights)
# Out:
# 4
