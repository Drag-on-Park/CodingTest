# %% [markdown]
# ### 문제 설명
# 단어 퍼즐은 주어진 단어 조각들을 이용해서 주어진 문장을 완성하는 퍼즐입니다.
# 이때, 주어진 각 단어 조각들은 각각 무한개씩 있다고 가정합니다. 예를 들어 주어진 단어 조각이 [“ba”, “na”, “n”, “a”]인 경우 "ba", "na", "n", "a" 단어 조각이 각각 무한개씩 있습니다.
# 이때, 만들어야 하는 문장이 “banana”라면 “ba”, “na”, “n”, “a”의 4개를 사용하여 문장을 완성할 수 있지만, “ba”, “na”, “na”의 3개만을 사용해도 “banana”를 완성할 수 있습니다.
# 사용 가능한 단어 조각들을 담고 있는 배열 strs와 완성해야 하는 문자열 t가 매개변수로 주어질 때, 주어진 문장을 완성하기 위해 사용해야 하는 단어조각 개수의 최솟값을 return 하도록 solution 함수를 완성해 주세요.
# 만약 주어진 문장을 완성하는 것이 불가능하면 -1을 return 하세요.
#
# ### 제한사항
# strs는 사용 가능한 단어 조각들이 들어있는 배열로, 길이는 1 이상 100 이하입니다.
# strs의 각 원소는 사용 가능한 단어조각들이 중복 없이 들어있습니다.
# 사용 가능한 단어 조각들은 문자열 형태이며, 모든 단어 조각의 길이는 1 이상 5 이하입니다.
# t는 완성해야 하는 문자열이며 길이는 1 이상 20,000 이하입니다.
# 모든 문자열은 알파벳 소문자로만 이루어져 있습니다.

# %%
# 길이 정렬
# 중복가능

# list형태 > 반복문에 t에 들어가는 단어 조합 
# dict형태 > 
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)

    for i in strs[::-1]:
        print(i)
        
    return answer

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
strs = ["app","ap","p","l","e","ple","pp"]	
t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
# Out:
# ple
# app
# pp
# ap
# e
# l
# p
# -1

# %%
# 길이 정렬
# 중복가능

# dict형태 > 

def solution(strs, t):
    answer = -1
    strs.sort(key=len)
    w_piece = {}

    for i in strs:
        if i not in w_piece:
            w_piece[i] = 1
    print(w_piece)

    

    

    return answer

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
strs = ["app","ap","p","l","e","ple","pp"]	
t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
# Out:
# {'p': 1, 'l': 1, 'e': 1, 'ap': 1, 'pp': 1, 'app': 1, 'ple': 1}
# -1

# %%
# 길이 정렬
# 중복가능
# 조각을 빼서 사용
# t를 분해해서 끼워 맞추기


# list형태 > 반복문에 t에 들어가는 단어 조합 
# dict형태 > 
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)

    for i in strs[::-1]:
        print(i)
        # 조각 리스트 초기화 / 문장 초기화
        strs_cp = strs[:]
        t_cp = t

        # 철자가 하나인 a같은 경우 세개 다 세어버림 
        count = t_cp.count(i)
        strs_cp.remove(i)
        # banana처럼 nana 반복 들어가면 다 삭제됨 / 삭제될 때 count
        # 한글자 중간중간 삭제됨 a > bnn\
        t_cp = t_cp.replace(i,"")
        
        print(f"t_cp:{t_cp} strs_cp:{strs_cp} count: {count}")
        for j in t_cp:
            pass
            
            
        
        
    return answer

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
strs = ["app","ap","p","l","e","ple","pp"]	
t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
# Out:
# ple
# t_cp:ap strs_cp:['p', 'l', 'e', 'ap', 'pp', 'app'] count: 1
# app
# t_cp:le strs_cp:['p', 'l', 'e', 'ap', 'pp', 'ple'] count: 1
# pp
# t_cp:ale strs_cp:['p', 'l', 'e', 'ap', 'app', 'ple'] count: 1
# ap
# t_cp:ple strs_cp:['p', 'l', 'e', 'pp', 'app', 'ple'] count: 1
# e
# t_cp:appl strs_cp:['p', 'l', 'ap', 'pp', 'app', 'ple'] count: 1
# l
# t_cp:appe strs_cp:['p', 'e', 'ap', 'pp', 'app', 'ple'] count: 1
# p
# t_cp:ale strs_cp:['l', 'e', 'ap', 'pp', 'app', 'ple'] count: 2
# -1

# %%
# 길이 정렬
# 중복가능
# 조각을 빼서 사용
# t를 분해해서 끼워 맞추기


# list형태 > 반복문에 t에 들어가는 단어 조합 
# dict형태 > 
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)

    for i in strs[::-1]:
        print(i)
        # 조각 리스트 초기화 / 문장 초기화
        strs_cp = strs[:]
        t_cp = t

        # 철자가 하나인 a같은 경우 세개 다 세어버림 
        count = t_cp.count(i)
        strs_cp.remove(i)
        # banana처럼 nana 반복 들어가면 다 삭제됨 / 삭제될 때 count
        # 한글자 중간중간 삭제됨 a > bnn\
        # 좌우로 놔눠야할지
        t_cp = t_cp.replace(i,"")
        print(f"t_cp:{t_cp} strs_cp:{strs_cp} count: {count}")
        
        if t_cp in strs_cp:
            count += 1
            t_cp = t_cp.replace(t_cp,"")
            print(f"t_cp: {t_cp}")
        
        if not t_cp:
            return count
        
    return answer

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
# strs = ["app","ap","p","l","e","ple","pp"]	
# t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
# Out:
# ban
# t_cp:ana strs_cp:['n', 'ba', 'an', 'nan'] count: 1
# nan
# t_cp:baa strs_cp:['n', 'ba', 'an', 'ban'] count: 1
# an
# t_cp:ba strs_cp:['n', 'ba', 'nan', 'ban'] count: 2
# t_cp:
# 3

# %%
# 제출 - 합계: 26.9 / 100.0
# 테스트케이스 3 >> return 3 반례잡아야됨
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)

    for i in strs[::-1]:
        strs_cp = strs[:]
        t_cp = t

        count = t_cp.count(i)
        strs_cp.remove(i)
        t_cp = t_cp.replace(i,"")
        
        if t_cp in strs_cp:
            count += 1
            t_cp = t_cp.replace(t_cp,"")
        
        if not t_cp:
            return count
        
    return answer

# %%
# 길이 정렬
# 중복가능
# 조각을 빼서 사용
# t를 분해해서 끼워 맞추기


# list형태 > 반복문에 t에 들어가는 단어 조합 
# dict형태 > 
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)
    # 남은 단어 조각
    rmd_list: []

    for i in strs[::-1]:
        print(i)
        # 조각 리스트 초기화 / 문장 초기화
        strs_cp = strs[:]
        t_cp = t

        # 철자가 하나인 a같은 경우 세개 다 세어버림 
        count = t_cp.count(i)
        strs_cp.remove(i)
        # banana처럼 nana 반복 들어가면 다 삭제됨 / 삭제될 때 count
        # 한글자 중간중간 삭제됨 a > bnn\
        # 좌우로 놔눠야할지
        t_cp = t_cp.replace(i," ")
        print(f"t_cp:{t_cp} strs_cp:{strs_cp} count: {count}")
        rmd_list = t_cp.split(" ")
        print(rmd_list)
        
        if t_cp in strs_cp:
            count += 1
            t_cp = t_cp.replace(t_cp,"")
            print(f"t_cp: {t_cp}")
        
        if not t_cp:
            return count
        
    return answer

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
# strs = ["app","ap","p","l","e","ple","pp"]	
# t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
# Out:
# na
# t_cp:ba   strs_cp:['n', 'a', 'ba'] count: 2
# ['ba', '', '']
# ba
# t_cp: nana strs_cp:['n', 'a', 'na'] count: 1
# ['', 'nana']
# a
# t_cp:b n n  strs_cp:['n', 'ba', 'na'] count: 3
# ['b', 'n', 'n', '']
# n
# t_cp:ba a a strs_cp:['a', 'ba', 'na'] count: 2
# ['ba', 'a', 'a']
# -1

# %%
# 길이 정렬
# 중복가능
# 조각을 빼서 사용
# t를 분해해서 끼워 맞추기
# 최솟값 인데 현재는 처음 t_cp가 비워지면 return

# list형태 > 반복문에 t에 들어가는 단어 조합 
# dict형태 > 
def solution(strs, t):
    answer = -1
    count = 0
    strs.sort(key=len)
    # 남은 단어 조각
    rmd_list = []
    min_frq = {}

    for i in strs[::-1]:
        print(i)
        # 조각 리스트 초기화 / 문장 초기화
        strs_cp = strs[:]
        t_cp = t

        # 철자가 하나인 a같은 경우 세개 다 세어버림 
        count = t_cp.count(i)
        strs_cp.remove(i)
        # banana처럼 nana 반복 들어가면 다 삭제됨 / 삭제될 때 count
        # 한글자 중간중간 삭제됨 a > bnn\
        # !!!! 좌우로 놔눠야할지
        t_cp = t_cp.replace(i,"")
        print(f"t_cp:{t_cp} strs_cp:{strs_cp} count: {count}")
        rmd_list = t_cp.split(" ")
        rmd_list_cp = rmd_list[:]
        print(rmd_list)
        
        for j in rmd_list:
            rmd_count = 0
            if not j :
                rmd_list_cp.remove(j)
                continue
            if j in strs_cp:
                rmd_count = t_cp.count(j)
                if rmd_count > 1:
                    print(f"rmd_count: {rmd_count}")
                    count += rmd_count
                    t_cp = t_cp.replace(j,"")
                    if not t_cp:
                        min_frq[i] = count
                        break


                    continue
                print(f"j in strs_cp j: {j}")
                count += 1
                t_cp = t_cp.replace(j,"")
            print(f"rmd_list t_cp: {t_cp} count: {count}")
        print(min_frq)

        # if rmd_list in strs_cp:
        #     count += 1
        #     t_cp = t_cp.replace(t_cp,"")
        #     print(f"t_cp: {t_cp}")
        if not t_cp:
            min_frq[i] = count

        
    return min(min_frq.values())

strs = ["ba","na","n","a"]	
t = "banana"
# result 3
strs = ["app","ap","p","l","e","ple","pp"]	
t = "apple"	
# result 2
# strs = ["ba","an","nan","ban","n"]	
# t = "banana"	
# result -1

solution(strs, t)
## le 일 때 l과 e가 들어있지만 le로만 검사함 l과 e 그리고 le까지 검사해야함 >> 남은 단어가 길어지면 ex_ appl처럼 길어지면 어떻게 해야할지
# Out:
# ple
# t_cp:ap strs_cp:['p', 'l', 'e', 'ap', 'pp', 'app'] count: 1
# ['ap']
# j in strs_cp j: ap
# rmd_list t_cp:  count: 2
# {}
# app
# t_cp:le strs_cp:['p', 'l', 'e', 'ap', 'pp', 'ple'] count: 1
# ['le']
# rmd_list t_cp: le count: 1
# {'ple': 2}
# pp
# t_cp:ale strs_cp:['p', 'l', 'e', 'ap', 'app', 'ple'] count: 1
# ['ale']
# rmd_list t_cp: ale count: 1
# {'ple': 2}
# ap
# t_cp:ple strs_cp:['p', 'l', 'e', 'pp', 'app', 'ple'] count: 1
# ['ple']
# j in strs_cp j: ple
# rmd_list t_cp:  count: 2
# {'ple': 2}
# e
# t_cp:appl strs_cp:['p', 'l', 'ap', 'pp', 'app', 'ple'] count: 1
# ['appl']
# rmd_list t_cp: appl count: 1
# {'ple': 2, 'ap': 2}
# l
# t_cp:appe strs_cp:['p', 'e', 'ap', 'pp', 'app', 'ple'] count: 1
# ['appe']
# rmd_list t_cp: appe count: 1
# {'ple': 2, 'ap': 2}
# p
# t_cp:ale strs_cp:['l', 'e', 'ap', 'pp', 'app', 'ple'] count: 2
# ['ale']
# rmd_list t_cp: ale count: 2
# {'ple': 2, 'ap': 2}
# 2
